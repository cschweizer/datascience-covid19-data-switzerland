# %% [markdown]
# # Describtive Analytics

# %%
import pandas as pd

df = pd.read_csv('../Data/CovidData.csv')
df['date'] = pd.to_datetime(df['date'])

df.head()
# Out:
#         date canton  daily_tested  ncumul_tested  daily_conf  ncumul_conf  \
# 0 2020-02-26     AG           NaN            NaN         NaN          1.0
# 1 2020-02-27     AG           NaN            NaN         0.0          1.0
# 2 2020-02-28     AG           NaN            NaN         0.0          1.0
# 3 2020-02-29     AG           NaN            NaN         2.0          3.0
# 4 2020-03-01     AG           NaN            NaN         1.0          4.0
#
#    seven_day_conf  testRelation  new_hosp  current_icu  current_vent  \
# 0             NaN           NaN       NaN          NaN           NaN
# 1             NaN           NaN       NaN          NaN           NaN
# 2             NaN           NaN       NaN          NaN           NaN
# 3             NaN           NaN       NaN          NaN           NaN
# 4             NaN           NaN       NaN          NaN           NaN
#
#    ncumul_released  daily_released  daily_deceased  ncumul_deceased  \
# ...

# %%
df.describe()
# Out:
#        daily_tested  ncumul_tested    daily_conf    ncumul_conf  \
# count    135.000000     241.000000  14692.000000   14816.000000
# mean     276.059259   46633.414938     63.730057   15799.355562
# std      235.952144   80278.203007    128.142053   23539.389482
# min        0.000000       1.000000     -2.000000       0.000000
# 25%       28.500000    3627.000000      4.000000     945.000000
# 50%      267.000000   22272.000000     18.000000    5095.500000
# 75%      436.500000   36472.000000     65.000000   20436.250000
# max     1056.000000  405204.000000   1642.000000  158032.000000
#
#        seven_day_conf  testRelation    new_hosp   current_icu  current_vent  \
# count    14182.000000    133.000000  981.000000  11186.000000   4867.000000
# mean        64.538681      0.082524    3.435270      8.406848      9.019725
# std        120.600836      0.107454    6.334481     14.263356     13.361997
# min         -0.285714      0.000000    0.000000      0.000000      0.000000
# ...
